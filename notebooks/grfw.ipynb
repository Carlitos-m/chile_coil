# %%
import polars as pl
df=pl.read_parquet('datos_correctos')
print(df.shape)
# Out:
# (203, 10)

# %%
# Out:
# shape: (10, 10)
# ┌───────────┬────────────────────────┬─────────┬──────┬───┬──────┬───────┬────────┬────────────────┐
# │ Grupo de  ┆ Alimento               ┆ Gramaje ┆ KCAL ┆ … ┆ PUFA ┆ SAT   ┆ SODIO  ┆ AZUCAR AÑADIDA │
# │ alimento  ┆ ---                    ┆ ---     ┆ ---  ┆   ┆ ---  ┆ ---   ┆ ---    ┆ ---            │
# │ ---       ┆ str                    ┆ i64     ┆ i64  ┆   ┆ str  ┆ str   ┆ str    ┆ str            │
# │ str       ┆                        ┆         ┆      ┆   ┆      ┆       ┆        ┆                │
# ╞═══════════╪════════════════════════╪═════════╪══════╪═══╪══════╪═══════╪════════╪════════════════╡
# │ Leche y   ┆ Leche entera           ┆ 100     ┆ 64   ┆ … ┆ 0.14 ┆ 2.28  ┆ 0.049  ┆ null           │
# │ derivados ┆                        ┆         ┆      ┆   ┆      ┆       ┆        ┆                │
# │ Leche y   ┆ Leche entera con sabor ┆ 100     ┆ 80   ┆ … ┆ 0.15 ┆ 1.84  ┆ 0.0596 ┆ null           │
# ...
