# %%
import polars as pl
df=pl.read_parquet('datos_correctos')
print(df.shape)
# Out:
# (203, 10)

# %%
df.columns
# Out:
# ['Grupo de alimento',
#  'Alimento',
#  'Gramaje',
#  'KCAL',
#  'PROT',
#  'MUFA',
#  'PUFA',
#  'SAT',
#  'SODIO',
#  'AZUCAR AÑADIDA']

# %%
print(list(df['Grupo de alimento'].unique()))
# Out:
# ['    FRUTAS ENTERAS', 'Productos salados', 'Legumbres', 'Bebidas ', 'Leche y derivados', 'Cereales', 'Salsas', '    AZUCARES Y MIEL', 'Pescados y mariscos', 'Carnes y visceras', '   JUGOS Y NECTARES', '         VERDURAS', 'Bebidas alcohólicas', 'Grasas y Aceites', 'Huevo']

# %%
df.head()
# Out:
# shape: (5, 10)
# ┌───────────┬─────────────────────────┬─────────┬──────┬───┬──────┬──────┬────────┬────────────────┐
# │ Grupo de  ┆ Alimento                ┆ Gramaje ┆ KCAL ┆ … ┆ PUFA ┆ SAT  ┆ SODIO  ┆ AZUCAR AÑADIDA │
# │ alimento  ┆ ---                     ┆ ---     ┆ ---  ┆   ┆ ---  ┆ ---  ┆ ---    ┆ ---            │
# │ ---       ┆ str                     ┆ i64     ┆ i64  ┆   ┆ str  ┆ str  ┆ str    ┆ str            │
# │ str       ┆                         ┆         ┆      ┆   ┆      ┆      ┆        ┆                │
# ╞═══════════╪═════════════════════════╪═════════╪══════╪═══╪══════╪══════╪════════╪════════════════╡
# │ Leche y   ┆ Leche entera            ┆ 100     ┆ 64   ┆ … ┆ 0.14 ┆ 2.28 ┆ 0.049  ┆ null           │
# │ derivados ┆                         ┆         ┆      ┆   ┆      ┆      ┆        ┆                │
# │ Leche y   ┆ Leche entera con sabor  ┆ 100     ┆ 80   ┆ … ┆ 0.15 ┆ 1.84 ┆ 0.0596 ┆ null           │
# ...

# %%
'    FRUTAS ENTERAS'
